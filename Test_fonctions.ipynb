# %%
import Fonctions_traitement as ft
import importlib
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage import io, filters, color
from typing import List, Tuple

# Forcer le rechargement après une modification du fichie
importlib.reload(ft)
# Out:
# <module 'Fonctions_traitement' from '/Users/martindrieux/Documents/GitHub/INF573_Puzzle-1/Fonctions_traitement.py'>

# %%
chateau=io.imread('chateau.jpg')
test_chateau=cv2.imread('/Users/martindrieux/Documents/GitHub/INF573_Puzzle-1/exemples/photos 1 pièce/photo_piece2.jpeg')
pieces=ft.extract_pieces(test_chateau)
plt.imshow(pieces[0]['image'])
# Out:
# Found 1 valid pieces
# Piece areas: [458013]

# %%
(kp_chateau, des_chateau)=ft.get_features(chateau)
(kp_piece, des_piece)=ft.get_features(pieces[0]['image'])
