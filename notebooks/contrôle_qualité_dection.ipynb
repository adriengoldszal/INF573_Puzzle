# %%
import sys
sys.path.append('../solver_adrien/')  # Ajouter le chemin du dossier contenant le fichier

from fonctions_image import *  # Importer toutes les fonctions du fichier

# Exemple d'utilisation

# %%
im1=cv2.imread('../exemples/test4.jpeg')
plt.imshow( im1)

# %%
pieces=extract_pieces(im1)
plt.imshow(pieces[1]['image'])
plt.imshow(pieces[1]['matching_image'])

print(len(pieces))
# Out:
# Found 18 valid pieces
# Piece areas: [17312, 41812, 67071, 34566, 42229, 26553, 27619, 66517, 38741, 35845, 31831, 36552, 37127, 35969, 22929, 34250, 38188, 65787]
# 18
